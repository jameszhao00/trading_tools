# %%
from datetime import datetime, timedelta

from stock_data_repo import StockDataRepo
from backtest import Backtester, BacktestResult
from strategies import MinVarianceAuxiliaryData, min_variance_portfolio

# %%
import plotly.express as px

# %%
backtester = Backtester(datetime(2017, 2, 1, 0, 0, 0))

# %%
FACTOR_CANDIDATES = [
    "SPY", # Large cap.
    "IWF", # Growth.
    "IWM", # Small cap.
    "MTUM", # Momentum.
    "VLUE", # Value.
#     "SDY", # Dividend.
]
LONG_CANDIDATES = [
    
#     "BLL", "APAM", "MTD", "ADM", "EXPI", "TMO", "PKI", "DHR", "GNRC", "HUBS", "SQ"
#     "PBW", "XNTK", "IGM",
#     "ARKQ", "ARKW", "ARKG", "ARKF",
#     "TAN"
#     "TSLA", "TWOU", "MTLS", "GOOG", "XLNX", "PRLB", "DE", "JD", "BYDDY", "KTOS",# "ARKW", "ARKG", "ARKF",
#     "ROKU", "SQ", "FB", "PINS", "WORK", "PSTG", "SPOT", "SNAP",
#     "MELI", "ICE", "TCEHY", "SE", "BABA", "Z"
    "ARKQ", "ARKW", "ARKG", "ARKF"
]
SHORT_CANDIDATES = [
#     "AFL", "ABBV", "AJRD", "AVA", "BXP", "CUZ", "GILD", "HII", "HIW", "KEX", "LYFT", "MGEE", "MSGS", "NJR", 
#     "OGS", "POR", "REG", "RTX", "SJI", "SWX", 
#     "XOM"
#     "XOM", "CVX"
    
] + FACTOR_CANDIDATES
r = backtester.backtest(LONG_CANDIDATES, SHORT_CANDIDATES, min_variance_portfolio)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
print("LONG FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(LONG_CANDIDATES))
print()
print("SHORT FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(SHORT_CANDIDATES))

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=1, shared_xaxes=True)

cum_returns = (r.returns_history+1).cumprod()
fig.add_trace(go.Scatter(x=cum_returns.index, y=cum_returns), row=1, col=1)
fig.update_yaxes(type="log", row=1, col=1)


long_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in LONG_CANDIDATES]]
for (k, v) in long_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=2, col=1)
    
short_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in SHORT_CANDIDATES]]
for (k, v) in short_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=3, col=1)

fig.update_layout(
    autosize=False,
    width=1000,
    height=1200,)
fig.show()

# %%
px.bar(long_allocations.iloc[-1])
# Out:
# <div>                            <div id="58a2eeed-f0a0-4976-8639-88e41d266db3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58a2eeed-f0a0-4976-8639-88e41d266db3")) {                    Plotly.newPlot(                        "58a2eeed-f0a0-4976-8639-88e41d266db3",                        [{"alignmentgroup": "True", "hovertemplate": "variable=2020-10-21 00:00:00<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "2020-10-21 00:00:00", "marker": {"color": "#636efa"}, "name": "2020-10-21 00:00:00", "offsetgroup": "2020-10-21 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["BABA", "BYDDY", "DE", "FB", "GOOG", "ICE", "JD", "KTOS", "MELI", "MTLS", "PINS", "PRLB", "PSTG", "ROKU", "SE", "SNAP", "SPOT", "SQ", "TCEHY", "TSLA", "TWOU", "WORK", "XLNX", "Z"], "xaxis": "x", "y": [0.0222670381304836, 0.003035469250280677, 0.16732504470040335, 0.06744563183500353, 0.12497401139340514, 0.1330824566510042, 0.017048525926233942, 0.08012807185329951, 0.02280760114765687, 0.0, 0.022766019377105078, 0.015967399891887397, 0.05507505509584598, 0.023161046197347088, 0.0, 0.038982909892303214, 0.009605388997463512, 0.017443552746475945, 0.04723689134683355, 0.04532412990145121, 0.009709343423842987, 0.0, 0.07636492161836252, 0.0002494906233107406], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.666666666666 ...

# %%
px.bar(short_allocations.iloc[-1])
# Out:
# <div>                            <div id="90989589-8b2e-48cf-9694-e75eb1717041" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90989589-8b2e-48cf-9694-e75eb1717041")) {                    Plotly.newPlot(                        "90989589-8b2e-48cf-9694-e75eb1717041",                        [{"alignmentgroup": "True", "hovertemplate": "variable=2020-10-21 00:00:00<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "2020-10-21 00:00:00", "marker": {"color": "#636efa"}, "name": "2020-10-21 00:00:00", "offsetgroup": "2020-10-21 00:00:00", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["CVX", "IWF", "IWM", "MTUM", "SPY", "VLUE", "XOM"], "xaxis": "x", "y": [-0.04257973304503306, -0.2694082914050481, -0.1494656742484095, -0.2637739614952805, -0.21063245873009273, -0.12538982909892304, -0.017859370451993848], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777 ...

# %% [markdown]
# ## Sorted by weight

# %%
import pyfolio as pf
pf.create_returns_tear_sheet(r.returns_history)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-02-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-21</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>20</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>30.264%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>57.837%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>11.569%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.34</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.50</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.66</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-12.084%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.49</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.69</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.17</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.35%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12.08</td>
#       <td>2019-02-28</td>
#       <td>2019-09-27</td>
#       <td>2020-02-21</td>
#       <td>257</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.75</td>
#       <td>2019-02-05</td>
#       <td>2019-02-20</td>
#       <td>2019-02-27</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.07</td>
#       <td>2020-03-10</td>
#       <td>2020-03-17</td>
#       <td>2020-03-19</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.90</td>
#       <td>2020-04-01</td>
#       <td>2020-04-09</td>
#       <td>2020-04-16</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.34</td>
#       <td>2020-05-26</td>
#       <td>2020-06-08</td>
#       <td>2020-06-15</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>

# %%
if False:
    r.save_most_recent_allocation("./allocations/", leverage=1.5)
