# %%
import numpy as np
import matplotlib.pylab as plt
import statsmodels.api as sm
import plotly.express as px
import pandas as pd
pd.options.plotting.backend = "plotly"

# %%
market_factor = yf.download('SPY')["Adj Close"]["2019-01-01":].pct_change()[1:]
momentum_factor = yf.download('MTUM')["Adj Close"]["2019-01-01":].pct_change()[1:]
value_factor = yf.download('VLUE')["Adj Close"]["2019-01-01":].pct_change()[1:]
qual_factor = yf.download('QUAL')["Adj Close"]["2019-01-01":].pct_change()[1:]
growth_factor = yf.download('IWF')["Adj Close"]["2019-01-01":].pct_change()[1:]

ticker_and_weights_csv = '''
AMZN,0.04772
CHWY,0.04723
CRWD,0.02534
DDOG,0.03484
DOCU,0.01752
FIVN,0.04221
FRPT,0.05415
ITB,0.05934
LULU,0.04883
NET,0.02353
NIO,0.01484
NVDA,0.01703
OKTA,0.03528
PBW,0.0378
PTON,0.03588
RH,0.0507
ROKU,0.02801
SE,0.03245
SHOP,0.02615
SNAP,0.04801
SPOT,0.03345
SQ,0.01345     
TRUP,0.02607
TSM,0.07899
TTD,0.00077
TWLO,0.02197
W,0.02558
ZG,0.03183
ZM,0.02136
ZS,0.01966
'''
stocks = yf.download(['AAPL'])["Adj Close"]["2019-01-01":].pct_change()[1:]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
weights = {"AAPL": .01, "ZM": .99}
prices = pd.DataFrame(data={"AAPL": stock1, "ZM": stock2})

# %%
portfolio_performance = ((pd.Series(weights)*prices).sum(axis=1))
(portfolio_performance+1).cumprod().plot()
# Out:
# <div>                            <div id="0c269556-c7bb-42be-8127-ca1f675bb4d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c269556-c7bb-42be-8127-ca1f675bb4d7")) {                    Plotly.newPlot(                        "0c269556-c7bb-42be-8127-ca1f675bb4d7",                        [{"hovertemplate": "variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "0", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "0", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00", "
# ...

# %%
#xs = sm.add_constant(np.column_stack([market_factor.values, tech_factor.values, momentum_factor.values]), prepend=False)
xs = sm.add_constant(np.column_stack([
#     market_factor.values, 
    growth_factor.values, 
#     momentum_factor.values,
#     value_factor.values, 
#     qual_factor.values
]), prepend=False)

# %%
from statsmodels.regression.rolling import RollingOLS
rlm_model = RollingOLS(portfolio_performance, xs, window=90)
rlm_results = rlm_model.fit()
rlm_results.params['x1'].plot()
# Out:
# <div>                            <div id="26708d95-892a-4347-a374-5a9dc43bb690" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26708d95-892a-4347-a374-5a9dc43bb690")) {                    Plotly.newPlot(                        "26708d95-892a-4347-a374-5a9dc43bb690",                        [{"hovertemplate": "variable=x1<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "x1", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "x1", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00"
# ...

# %%
rlm_results.rsquared_adj.plot()
# Out:
# <div>                            <div id="ae7a066c-6a8f-4e2c-b6d3-bc8dae3dc2c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae7a066c-6a8f-4e2c-b6d3-bc8dae3dc2c3")) {                    Plotly.newPlot(                        "ae7a066c-6a8f-4e2c-b6d3-bc8dae3dc2c3",                        [{"hovertemplate": "variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "0", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "0", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2019-01-03T00:00:00", "2019-01-04T00:00:00", "2019-01-07T00:00:00", "2019-01-08T00:00:00", "2019-01-09T00:00:00", "2019-01-10T00:00:00", "2019-01-11T00:00:00", "2019-01-14T00:00:00", "2019-01-15T00:00:00", "2019-01-16T00:00:00", "
# ...

# %%
fig = rlm_results.plot_recursive_coefficient(variables=['x1', 'const'], figsize=(14,6))
