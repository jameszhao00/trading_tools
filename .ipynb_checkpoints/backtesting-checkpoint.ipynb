# %%
from datetime import datetime, timedelta

from stock_data_repo import StockDataRepo
from backtest import Backtester, BacktestResult
from strategies import MinVarianceAuxiliaryData, min_variance_portfolio

# %%
backtester = Backtester(datetime(2020, 2, 1, 0, 0, 0))

# %%
LONG_FACTOR_CANDIDATES = [
#     "VLUE", # Value.
#     "USMV", # Low volatility.
#     "SDY", # Dividend.
    "VXX"
]
SHORT_FACTOR_CANDIDATES = [
    "SPY", # Large cap.
    "IWF", # Growth.
    "IWM", # Small cap.
    "MTUM", # Momentum.
]
LONG_CANDIDATES = [
    "AMZN",
    "BLK",
    "BABA",
    "DDOG",
    "FDX",
    "FIVN",
    "NVDA",
    "PBW",
    "PINS",
    "PTON",
    "SNAP",
    "SE",
    "SQ",
    "TTD",
    "TWLO",
    "TSLA",
    "UPS",
    "ZG",
    "SHOP",
    "UBER",
    "ARKK",
    "MCHI"
#     "SNOW" # Not enough data yet.
#     "U" # Not enough data yet.
] + LONG_FACTOR_CANDIDATES
SHORT_CANDIDATES = [
    "VRSN",
    "CSCO",
    "IBM",
    "BOX",
    "CLDR",
    "EQR",
    "NEWR",
    "VMW",
    "GDDY",
#     "RXT" # Rackspace. Not enough data yet.
    "ORCL",
    # Uber will outperform lyft because it's in the deliveries instead of transportations business.
    "LYFT", 
    "PS", # Who takes pluralsight training??
    "GRPN",
#     "APPS", # Pre-installed android crapware. But I don't know the business model.
    "DT" # Inferior to datadog.
] + SHORT_FACTOR_CANDIDATES

r = backtester.backtest(LONG_CANDIDATES, SHORT_CANDIDATES, min_variance_portfolio)
# Out:
# [*********************100%***********************]  42 of 42 completed

# %%
print("LONG FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(LONG_CANDIDATES))
print()
print("SHORT FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(SHORT_CANDIDATES))
# Out:
# LONG FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=AMZN,BLK,BABA,DDOG,FDX,FIVN,NVDA,PBW,PINS,PTON,SNAP,SE,SQ,TTD,TWLO,TSLA,UPS,ZG,SHOP,UBER,ARKK,MCHI,VXX
#
# SHORT FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=VRSN,CSCO,IBM,BOX,CLDR,EQR,NEWR,VMW,GDDY,ORCL,LYFT,PS,GRPN,APPS,DT,SPY,IWF,IWM,MTUM

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=1, shared_xaxes=True)

cum_returns = (r.returns_history+1).cumprod()
fig.add_trace(go.Scatter(x=cum_returns.index, y=cum_returns), row=1, col=1)
fig.update_yaxes(type="log", row=1, col=1)


long_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in LONG_CANDIDATES]]
for (k, v) in long_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=2, col=1)
    
short_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in SHORT_CANDIDATES]]
for (k, v) in short_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=3, col=1)

fig.update_layout(
    autosize=False,
    width=1000,
    height=1200,)
fig.show()
# Out:
# <div>                            <div id="527e8911-d44e-4413-8c21-fdefe6b8bd44" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("527e8911-d44e-4413-8c21-fdefe6b8bd44")) {                    Plotly.newPlot(                        "527e8911-d44e-4413-8c21-fdefe6b8bd44",                        [{"type": "scatter", "x": ["2020-02-03T00:00:00", "2020-02-04T00:00:00", "2020-02-05T00:00:00", "2020-02-06T00:00:00", "2020-02-07T00:00:00", "2020-02-10T00:00:00", "2020-02-11T00:00:00", "2020-02-12T00:00:00", "2020-02-13T00:00:00", "2020-02-14T00:00:00", "2020-02-18T00:00:00", "2020-02-19T00:00:00", "2020-02-20T00:00:00", "2020-02-21T00:00:00", "2020-02-24T00:00:00", "2020-02-25T00:00:00", "2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-28T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T0 ...

# %% [markdown]
# # Proposed Allocation

# %% [markdown]
# ## Sorted A-Z

# %%
import plotly.express as px
data = r.allocation_history.iloc[-1]
px.bar(x=data.index, y=data)
# Out:
# <div>                            <div id="6bd38e04-99f9-4be8-b77c-1058801ff57f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bd38e04-99f9-4be8-b77c-1058801ff57f")) {                    Plotly.newPlot(                        "6bd38e04-99f9-4be8-b77c-1058801ff57f",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["AMZN", "APPS", "ARKK", "BABA", "BLK", "BOX", "CLDR", "CSCO", "DDOG", "DT", "EQR", "FDX", "FIVN", "GDDY", "GRPN", "IBM", "IWF", "IWM", "LYFT", "MCHI", "MTUM", "NEWR", "NVDA", "ORCL", "PBW", "PINS", "PS", "PTON", "SE", "SHOP", "SNAP", "SPY", "SQ", "TSLA", "TTD", "TWLO", "UBER", "UPS", "VMW", "VRSN", "VXX", "ZG"], "xaxis": "x", "y": [0.09588215740048202, -0.007354774370481178, 0.07188564780187817, 0.011052937754508437, 0.13519072550486166, -0.03425995179921883, -0.0503407296601014, -0.026364996260284223, 0.020298346214576584, -0.04730740463724757, -0.052085930358181674, 0.07626942574586555, 0.04745283802875427, -0.07469043463807863, -0.0, -0.006793817003241088, -0.14042632759910248, -0.091539931854068, -0.015935344469375886, 0.06054184326435636, -0.15282971827474448, -0.0023477104628937093, 0.08042466550319956, -0.062474029751516676, 0.06056261946314303, 0.014854982132469047, -0.04786836200448767, 0.0020152912823069896, 0.014481010554308985, 0.026614310645724264, 0.03754259120751268, -0.11102800631596445, 0.0033449680046538696, 0.0, 0.011987866699908587, 0.020713870190309985, 0.07710047369733235, 0.08821574004820079, -0.0557425413446356, -0.09822986786337574, 0.011281475941161807, 0.03228621291448517], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888,  ...

# %% [markdown]
# ## Sorted by weight

# %%
print(data[data!=0].sort_values())
# Out:
# MTUM   -0.152830
# IWF    -0.140426
# SPY    -0.111028
# VRSN   -0.098230
# IWM    -0.091540
# GDDY   -0.074690
# ORCL   -0.062474
# VMW    -0.055743
# EQR    -0.052086
# CLDR   -0.050341
# PS     -0.047868
# DT     -0.047307
# BOX    -0.034260
# CSCO   -0.026365
# LYFT   -0.015935
# APPS   -0.007355
# IBM    -0.006794
# NEWR   -0.002348
# PTON    0.002015
# SQ      0.003345
# BABA    0.011053
# VXX     0.011281
# TTD     0.011988
# SE      0.014481
# PINS    0.014855
# DDOG    0.020298
# TWLO    0.020714
# SHOP    0.026614
# ZG      0.032286
# SNAP    0.037543
# FIVN    0.047453
# MCHI    0.060542
# PBW     0.060563
# ARKK    0.071886
# FDX     0.076269
# UBER    0.077100
# NVDA    0.080425
# UPS     0.088216
# AMZN    0.095882
# BLK     0.135191
# Name: 2020-10-29 00:00:00, dtype: float64

# %%
import pyfolio as pf
pf.create_returns_tear_sheet(r.returns_history)
# Out:
# /Users/jameszhao/.local/share/virtualenvs/trading_tools-DCkkE-wc/lib/python3.8/site-packages/pyfolio/pos.py:26: UserWarning:
#
# Module "zipline.assets" not found; multipliers will not be applied to position notionals.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-02-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>9</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>155.433%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>102.049%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>12.89%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>7.35</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>43.43</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-3.579%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>3.46</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>17.03</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>2.03</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.248%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3.58</td>
#       <td>2020-03-25</td>
#       <td>2020-04-09</td>
#       <td>2020-04-16</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.03</td>
#       <td>2020-03-12</td>
#       <td>2020-03-13</td>
#       <td>2020-03-17</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.96</td>
#       <td>2020-06-24</td>
#       <td>2020-06-26</td>
#       <td>2020-07-01</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.93</td>
#       <td>2020-10-07</td>
#       <td>2020-10-12</td>
#       <td>2020-10-15</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.61</td>
#       <td>2020-03-03</td>
#       <td>2020-03-04</td>
#       <td>2020-03-05</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>

# %%
if True:
    r.save_most_recent_allocation("./allocations/", leverage=1.5)
