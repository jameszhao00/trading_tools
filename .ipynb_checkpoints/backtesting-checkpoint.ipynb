# %%
from datetime import datetime, timedelta

from stock_data_repo import StockDataRepo
from backtest import Backtester, BacktestResult
from strategies import MinVarianceAuxiliaryData, min_variance_portfolio

# %%
backtester = Backtester(datetime(2020, 3, 1, 0, 0, 0))

# %%
SHORT_FACTORS = [
    "QQQ", 
    "SPY", # Large cap.
    "IWF", # Growth.
    "IWM", # Small cap.
    "MTUM", # Momentum.
    "VLUE", # Value.
    "USMV", # Low volatility.
    "SDY", # Dividend.   
]
LONG_FACTORS = ["VXX"]
LONG_CANDIDATES = [
    "AMD",
    "BYND",
    "COUP",
    "CRSP", 
    "CRWD",
    "DDOG",
    "DOCU",
    "FIVN",
    "HUBS",
    "ISRG",
    "ITB",
    "LULU",
    "NET",
    "NIO",
    "NVDA",
    "NVTA",
    "PBW",
    "PTON",
    "RH",
    "ROKU",
    "SE",
    "SNAP",
    "SPOT",
    "TEAM",
    "TRUP",
    "TTD",
    "TXG",
    "W",
    "ZG",
    "ZM",
    "DAO", # Youdao.
    # ECommerce.
    "MELI",
    "AMZN",
    "BABA",
    "CHWY",
    "CVNA",
    "FRPT",
    "SHOP",
    # Streaming entertainment.
    "NFLX",
    # Home.
    "BBBY",
    # Saas.
    "CRM",
    "PAYC",
    "TDOC",
    "SQ",
    "VEEV",
    "ZS",
    "OKTA",
    "TWLO",
    "AYX",
    "NOW",
    "MDB",
    "FSLY",
    # Online dating.
    "IAC",
    # Delivery.
    "FDX",
    "UPS",
    "UBER",
    # Index investing.
    "BLK",
    "MSCI",
    # Online education.
    # Social media.
    "PINS",
    # Gig economy/freelancing.
    "FVRR",
#     "LOGI"
] + LONG_FACTORS
SHORT_CANDIDATES = [
    # Movie theatres.
    "AMC", 
    # Airlines.
    "DAL", 
    "UAL", 
    # Finance.
    "WFC", 
    # Oil.
    "XOM",
    "CVX",
    # Cloud losers.
    "SPLK",
    "PD",
    "ZEN",
    # Old ecommerce.
    "EBAY",
    # Old tech.
    "MSFT",
    "GRUB",
    "CSCO",
    "DBX",
    "BOX",
    "NLOK",
    "CLDR",
    "IBM",
    "ORCL",
    "SAP",
    "VRSN",
    "VMW",
    "NEWR", # New relic.
    "DT", # Dynatrace.
    "SWI", # SolarWinds. Previously owned by PE.
    "DOMO",
    # Tobacco.
    "MO",
    "PM",
    # Commercial real estate.
    "EQR",
    "VNQ",
    "AVB", # Caters to immigrants... and there's less immigration due to policies.
    "T"
] + SHORT_FACTORS
r = backtester.backtest(LONG_CANDIDATES, SHORT_CANDIDATES, min_variance_portfolio)

# %%
print("LONG FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(LONG_CANDIDATES))
print()
print("SHORT FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(SHORT_CANDIDATES))
# Out:
# LONG FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=AMD,BYND,COUP,CRSP,CRWD,DDOG,DOCU,FIVN,HUBS,ISRG,ITB,LULU,NET,NIO,NVDA,NVTA,PBW,PTON,RH,ROKU,SE,SNAP,SPOT,TEAM,TRUP,TTD,TXG,W,ZG,ZM,DAO,MELI,AMZN,BABA,CHWY,CVNA,FRPT,SHOP,NFLX,BBBY,CRM,PAYC,TDOC,SQ,VEEV,ZS,OKTA,TWLO,AYX,NOW,MDB,FSLY,IAC,FDX,UPS,UBER,BLK,MSCI,PINS,FVRR,VXX
#
# SHORT FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=AMC,DAL,UAL,WFC,XOM,CVX,SPLK,PD,ZEN,EBAY,MSFT,GRUB,CSCO,DBX,BOX,NLOK,CLDR,IBM,ORCL,SAP,VRSN,VMW,NEWR,DT,SWI,DOMO,MO,PM,EQR,VNQ,AVB,T,QQQ,SPY,IWF,IWM,MTUM,VLUE,USMV,SDY

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=1, shared_xaxes=True)

cum_returns = (r.returns_history+1).cumprod()
fig.add_trace(go.Scatter(x=cum_returns.index, y=cum_returns), row=1, col=1)
fig.update_yaxes(type="log", row=1, col=1)


long_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in LONG_CANDIDATES]]
for (k, v) in long_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=2, col=1)
    
short_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in SHORT_CANDIDATES]]
for (k, v) in short_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=3, col=1)

fig.update_layout(
    autosize=False,
    width=1000,
    height=1200,)
fig.show()
# Out:
# <div>                            <div id="cc36d638-2fe1-4268-ab4c-86bc06bcdf38" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc36d638-2fe1-4268-ab4c-86bc06bcdf38")) {                    Plotly.newPlot(                        "cc36d638-2fe1-4268-ab4c-86bc06bcdf38",                        [{"type": "scatter", "x": ["2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00", "2020-10-01T0 ...

# %% [markdown]
# # Proposed Allocation

# %% [markdown]
# ## Sorted A-Z

# %%
import plotly.express as px
data = r.allocation_history.iloc[-1]
px.bar(x=data.index, y=data)
# Out:
# <div>                            <div id="83f8a3d6-231f-45d9-b8c9-9b8862423743" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83f8a3d6-231f-45d9-b8c9-9b8862423743")) {                    Plotly.newPlot(                        "83f8a3d6-231f-45d9-b8c9-9b8862423743",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["AMC", "AMD", "AMZN", "AVB", "AYX", "BABA", "BBBY", "BLK", "BOX", "BYND", "CHWY", "CLDR", "COUP", "CRM", "CRSP", "CRWD", "CSCO", "CVNA", "CVX", "DAL", "DAO", "DBX", "DDOG", "DOCU", "DOMO", "DT", "EBAY", "EQR", "FDX", "FIVN", "FRPT", "FSLY", "FVRR", "GRUB", "HUBS", "IAC", "IBM", "ISRG", "ITB", "IWF", "IWM", "LULU", "MDB", "MELI", "MO", "MSCI", "MSFT", "MTUM", "NET", "NEWR", "NFLX", "NIO", "NLOK", "NOW", "NVDA", "NVTA", "OKTA", "ORCL", "PAYC", "PBW", "PD", "PINS", "PM", "PTON", "QQQ", "RH", "ROKU", "SAP", "SDY", "SE", "SHOP", "SNAP", "SPLK", "SPOT", "SPY", "SQ", "SWI", "T", "TDOC", "TEAM", "TRUP", "TTD", "TWLO", "TXG", "UAL", "UBER", "UPS", "USMV", "VEEV", "VLUE", "VMW", "VNQ", "VRSN", "VXX", "W", "WFC", "XOM", "ZEN", "ZG", "ZM", "ZS"], "xaxis": "x", "y": [-0.0, 0.012591414944356122, 0.06104928457869634, -0.00498145204027557, 0.009326974032856386, 0.010598834128245893, 0.017148913619501854, 0.051531531531531526, -0.01695813460519343, 0.0, 0.00570217276099629, -0.02706942236354001, 0.007906730259671436, 0.035463698993110755, 0.008881822999470058, 0.009009009009009009, -0.0, 0.0, -0.0019289878113407525, -0.0, 0.009009009009009009, -0.04813990461049285, 0.007737148913619502, 0.0, -0.00570217276099629, -0.05492315845257022, -0.03798622151563328, -0.013587705352411234, 0.051722310545839964, 0.0, 0.007652358240593534, 0.0, 0.0, -0.03883412824589295, 0.01483836777954425, 0.014753577106518282, -0.0, 0.08913619501854796, 0.048033916269210386, -0.07135135135135136, -0.049411764705882356, 0.04343402225755167, 0.025225225225225228, 0.019798622151563326, -0.025204027556968732, 0.025606783253842077, -0.057000529941706415, -0.07397986221515633, 0.01413884472708002, -0.004854266030736618, 0.0, 0.006825649178590356, -0.014075251722310545, 0.03016428192898781, 0.039236883942766296, 0.008267090620031796, 0.023529411764705882, -0.020837307896131425, 0.006846846846846846, 0.047397986221515635, -0.04152623211446741, 0.0022045574986751457, -0.012103868574456809, 0.015177530471648118, -0.0714997350291468, 0.0, 0.015474297827239004, -0.004621091679915209, -0.019162692103868572, 0.0, 0.0, 0.007186009538950715, -0.0474827768945416, 0.018124006359300476, -0.04905140434552199, 0.0, -0.03985161632220456, -0.026285108638049812, 0.0, 0.013142554319024906, 0.0030100688924218338, 0.0, 0.0, 0.021176470588235297, -0.0, 0.0479915209326974, 0.040763116057233706, -0.0423317435082141, 0.040105988341282456, -0.017254901960784313, -0.03336512983571807, -0.02834128245892952, -0.05799682034976152, 0.009666136724960254, 0.0, -0.0, -0.0, -0.062109167991520935, 0.0, 0.0, 0.003412824589295178], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "wh ...

# %% [markdown]
# ## Sorted by weight

# %%
print(data[data!=0].sort_values())
# Out:
# MTUM   -0.073980
# QQQ    -0.071500
# IWF    -0.071351
# ZEN    -0.062109
# VRSN   -0.057997
#           ...
# ITB     0.048034
# BLK     0.051532
# FDX     0.051722
# AMZN    0.061049
# ISRG    0.089136
# Name: 2020-10-21 00:00:00, Length: 77, dtype: float64

# %%
import pyfolio as pf
pf.create_returns_tear_sheet(r.returns_history)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-03-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-21</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>7</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>97.693%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>55.822%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>11.32%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>6.09</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>28.75</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-3.398%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>2.66</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>12.00</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.11</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.51</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.153%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3.40</td>
#       <td>2020-03-26</td>
#       <td>2020-04-03</td>
#       <td>2020-04-15</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.83</td>
#       <td>2020-03-05</td>
#       <td>2020-03-13</td>
#       <td>2020-03-18</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.01</td>
#       <td>2020-05-21</td>
#       <td>2020-05-29</td>
#       <td>2020-06-10</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.23</td>
#       <td>2020-04-16</td>
#       <td>2020-04-17</td>
#       <td>2020-04-21</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.19</td>
#       <td>2020-09-01</td>
#       <td>2020-09-02</td>
#       <td>2020-09-03</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>

# %%
if False:
    r.save_most_recent_allocation("./allocations/", leverage=1.5)
