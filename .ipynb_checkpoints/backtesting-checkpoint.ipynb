# %%
from datetime import datetime, timedelta

from stock_data_repo import StockDataRepo
from backtest import Backtester, BacktestResult
from strategies import MinVarianceAuxiliaryData, min_variance_portfolio

# %%
backtester = Backtester(datetime(2020, 3, 1, 0, 0, 0))

# %%
FACTOR_HEDGE_CANDIDATES = [
    "VXX",
]
FACTOR_SHORT_CANDIDATES = [
    "IWF",
    "QQQ",
    "SPY",
    "IWM"
]

LONG_CANDIDATES = [
    "AMD",
    "BYND",
    "COUP",
    "CRSP", 
    "CRWD",
    "DDOG",
    "DOCU",
    "FIVN",
    "HUBS",
    "ISRG",
    "ITB",
    "LULU",
    "NET",
    "NIO",
    "NVDA",
    "NVTA",
    "PBW",
    "PTON",
    "RH",
    "ROKU",
    "SE",
    "SNAP",
    "SPOT",
    "TEAM",
    "TRUP",
    "TTD",
    "TXG",
    "UBER",
    "W",
    "ZG",
    "ZM",
    "DAO", # Youdao.
    # ECommerce.
    "MELI",
    "AMZN",
    "BABA",
    "CHWY",
    "CVNA",
    "FRPT",
    # Streaming entertainment.
    "NFLX",
    # Home.
    "BBBY",
    # Saas.
    "CRM",
    "PAYC",
    "TDOC",
    "SHOP",
    "SQ",
    "VEEV",
    "ZS",
    "OKTA",
    "TWLO",
    "AYX",
    "WDAY",
    "NOW",
    "MDB",
    "FSLY",
    "ZEN",
    # Online dating.
    "IAC",
    # Delivery.
    "GRUB",
    # Index investing.
    "BLK",
    "MSCI",
    # Online education.
    "GSX",
    # Social media.
    "PINS",
    # Gig economy/freelancing.
    "FVRR"
] + FACTOR_HEDGE_CANDIDATES
SHORT_CANDIDATES = [
    # Movie theatres.
    "AMC", 
    # Airlines.
    "DAL", 
    "UAL", 
    # Finance.
    "WFC", 
    # Oil.
    "XOM",
    "CVX",
    # Old tech.
    "CSCO",
    "DBX",
    "BOX",
    "NLOK",
    "CLDR",
    "IBM",
    "ORCL",
    "SAP",
    "VRSN",
    "VMW",
    "NEWR", # New relic.
    "DT", # Dynatrace.
    "SWI", # SolarWinds. Previously owned by PE.
    "DOMO",
    # Tobacco.
    "MO",
    "PM",
    # Commercial real estate.
    "EQR",
    "VNQ"
] + FACTOR_SHORT_CANDIDATES
r = backtester.backtest(LONG_CANDIDATES, SHORT_CANDIDATES, min_variance_portfolio)
# Out:
# [*********************100%***********************]  91 of 91 completed
# Optimizing portfolio for 2020-03-02 00:00:00
# Optimizing portfolio for 2020-03-03 00:00:00
# Optimizing portfolio for 2020-03-04 00:00:00
# Optimizing portfolio for 2020-03-05 00:00:00
# Optimizing portfolio for 2020-03-06 00:00:00
# Optimizing portfolio for 2020-03-09 00:00:00
# Optimizing portfolio for 2020-03-10 00:00:00
# Optimizing portfolio for 2020-03-11 00:00:00
# Optimizing portfolio for 2020-03-12 00:00:00
# Optimizing portfolio for 2020-03-13 00:00:00
# Optimizing portfolio for 2020-03-16 00:00:00
# Optimizing portfolio for 2020-03-17 00:00:00
# Optimizing portfolio for 2020-03-18 00:00:00
# Optimizing portfolio for 2020-03-19 00:00:00
# Optimizing portfolio for 2020-03-20 00:00:00
# Optimizing portfolio for 2020-03-23 00:00:00
# Optimizing portfolio for 2020-03-24 00:00:00
# Optimizing portfolio for 2020-03-25 00:00:00
# Optimizing portfolio for 2020-03-26 00:00:00
# Optimizing portfolio for 2020-03-27 00:00:00
# Optimizing portfolio for 2020-09-18 00:00:00
# Optimizing portfolio for 2020-09-21 00:00:00
# Optimizing portfolio for 2020-09-22 00:00:00
# Optimizing portfolio for 2020-09-23 00:00:00
# Optimizing portfolio for 2020-09-24 00:00:00
# Optimizing portfolio for 2020-09-25 00:00:00
# Optimizing portfolio for 2020-09-28 00:00:00
# Optimizing portfolio for 2020-09-29 00:00:00
# Optimizing portfolio for 2020-09-30 00:00:00
# Optimizing portfolio for 2020-10-01 00:00:00
# Optimizing portfolio for 2020-10-02 00:00:00
# Optimizing portfolio for 2020-10-05 00:00:00
# Optimizing portfolio for 2020-10-06 00:00:00
# Optimizing portfolio for 2020-10-07 00:00:00
# Optimizing portfolio for 2020-10-08 00:00:00
# Optimizing portfolio for 2020-10-09 00:00:00
# Optimizing portfolio for 2020-10-12 00:00:00
# Optimizing portfolio for 2020-10-13 00:00:00
# Optimizing portfolio for 2020-10-14 00:00:00
# Optimizing portfolio for 2020-10-15 00:00:00
# Optimizing portfolio for 2020-10-16 00:00:00

# %%
print("LONG FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(LONG_CANDIDATES))
print()
print("SHORT FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(SHORT_CANDIDATES))
# Out:
# LONG FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=AMD,BYND,COUP,CRSP,CRWD,DDOG,DOCU,FIVN,HUBS,ISRG,ITB,LULU,NET,NIO,NVDA,NVTA,PBW,PTON,RH,ROKU,SE,SNAP,SPOT,TEAM,TRUP,TTD,TXG,UBER,W,ZG,ZM,DAO,MELI,AMZN,BABA,CHWY,CVNA,FRPT,NFLX,BBBY,CRM,PAYC,TDOC,SHOP,SQ,VEEV,ZS,OKTA,TWLO,AYX,WDAY,NOW,MDB,FSLY,ZEN,IAC,GRUB,BLK,MSCI,GSX,PINS,FVRR,VXX
#
# SHORT FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=AMC,DAL,UAL,WFC,XOM,CVX,CSCO,DBX,BOX,NLOK,CLDR,IBM,ORCL,SAP,VRSN,VMW,NEWR,DT,SWI,DOMO,MO,PM,EQR,VNQ,IWF,QQQ,SPY,IWM

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=1, shared_xaxes=True)

cum_returns = (r.returns_history+1).cumprod()
fig.add_trace(go.Scatter(x=cum_returns.index, y=cum_returns), row=1, col=1)
fig.update_yaxes(type="log", row=1, col=1)


long_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in LONG_CANDIDATES]]
for (k, v) in long_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=2, col=1)
    
short_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in SHORT_CANDIDATES]]
for (k, v) in short_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=3, col=1)

fig.update_layout(
    autosize=False,
    width=1000,
    height=1200,)
fig.show()
# Out:
# <div>                            <div id="67743fbd-8f2c-41ff-872d-c2d6ec0a087d" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67743fbd-8f2c-41ff-872d-c2d6ec0a087d")) {                    Plotly.newPlot(                        "67743fbd-8f2c-41ff-872d-c2d6ec0a087d",                        [{"type": "scatter", "x": ["2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00", "2020-10-01T0 ...

# %% [markdown]
# # Proposed Allocation

# %% [markdown]
# ## Sorted A-Z

# %%
import plotly.express as px
data = r.allocation_history.iloc[-1]
px.bar(x=data.index, y=data)
# Out:
# <div>                            <div id="56db84b4-3287-4cd7-8785-60533b9feaae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56db84b4-3287-4cd7-8785-60533b9feaae")) {                    Plotly.newPlot(                        "56db84b4-3287-4cd7-8785-60533b9feaae",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["AMC", "AMD", "AMZN", "AYX", "BABA", "BBBY", "BLK", "BOX", "BYND", "CHWY", "CLDR", "COUP", "CRM", "CRSP", "CRWD", "CSCO", "CVNA", "CVX", "DAL", "DAO", "DBX", "DDOG", "DOCU", "DOMO", "DT", "EQR", "FIVN", "FRPT", "FSLY", "FVRR", "GRUB", "GSX", "HUBS", "IAC", "IBM", "ISRG", "ITB", "IWF", "IWM", "LULU", "MDB", "MELI", "MO", "MSCI", "NET", "NEWR", "NFLX", "NIO", "NLOK", "NOW", "NVDA", "NVTA", "OKTA", "ORCL", "PAYC", "PBW", "PINS", "PM", "PTON", "QQQ", "RH", "ROKU", "SAP", "SE", "SHOP", "SNAP", "SPOT", "SPY", "SQ", "SWI", "TDOC", "TEAM", "TRUP", "TTD", "TWLO", "TXG", "UAL", "UBER", "VEEV", "VMW", "VNQ", "VRSN", "VXX", "W", "WDAY", "WFC", "XOM", "ZEN", "ZG", "ZM", "ZS"], "xaxis": "x", "y": [-0.0, 0.011414329696106562, 0.0508723061134731, 0.00626217353969883, 0.026430979956855928, 0.01681781054307077, 0.07070601294322157, -0.046516011477160876, 0.009466563344293882, 0.006429723333403146, -0.051291180597733896, 0.0, 0.01979181938132239, 0.004733281672146941, 0.0018430477307474818, -0.026389092508429853, 0.0, -0.01931011372442248, -0.0, 0.001968710076025719, -0.07414078371416007, 0.0, 0.0, -0.04259953504932248, -0.08080088801390665, -0.018158208892705304, 0.0, 0.026326261335790732, 0.003958363876264478, 0.0, 0.00869164554841142, 0.0, 0.021236936352022118, 0.01912162020650512, -0.02299620918591744, 0.06787861017446123, 0.05910318972919765, -0.08498963285651455, -0.052401197981024994, 0.020126918968731023, 0.01539363729658408, 0.016189498816679585, -0.028651014723438124, 0.02603304919680818, 0.009696944310637317, -0.015184200054453685, 0.008817307893689657, 0.00720464112928561, -0.04176178608080089, 0.027226841476951435, 0.030975768111085517, 0.0022200347665821936, 0.01910067648229208, -0.049385301694347294, 0.008733532996837498, 0.055228600749785334, 0.017069135233627245, -0.03036840010890737, 0.0, -0.08800552914319225, 0.01399040777431043, 0.020713343246696127, -0.037426435168701706, 0.0061574549186336315, 0.0, 0.019519550966552876, 0.01677592309464469, -0.062349466982218785, 0.0, -0.05868431524493686, 0.0, 0.009361844723228686, 0.012670953148888936, 0.0, 0.0, 0.026703248371625445, -0.0, 0.04819150941420404, 0.03168785473432886, -0.052610635223155386, -0.035101681781054314, -0.07401512136888183, 0.011770373007728235, 0.0, 0.014137013843801706, -0.0, -0.001151904831717176, 0.038745889794123196, 0.030619724799463843, 0.0, 0.0018849351791735609], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [ ...

# %% [markdown]
# ## Sorted by weight

# %%
print(data[data!=0].sort_values())
# Out:
# QQQ    -0.088006
# IWF    -0.084990
# DT     -0.080801
# DBX    -0.074141
# VRSN   -0.074015
#           ...
# AMZN    0.050872
# PBW     0.055229
# ITB     0.059103
# ISRG    0.067879
# BLK     0.070706
# Name: 2020-10-16 00:00:00, Length: 72, dtype: float64

# %%
import pyfolio as pf
pf.create_returns_tear_sheet(r.returns_history)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-03-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-16</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>7</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>124.772%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>67.774%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.507%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>6.07</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>30.68</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-4.067%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>2.68</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>11.75</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.38</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.376%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.07</td>
#       <td>2020-03-25</td>
#       <td>2020-04-03</td>
#       <td>2020-04-13</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.94</td>
#       <td>2020-03-05</td>
#       <td>2020-03-13</td>
#       <td>2020-03-20</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.55</td>
#       <td>2020-05-22</td>
#       <td>2020-05-27</td>
#       <td>2020-06-11</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.06</td>
#       <td>2020-08-06</td>
#       <td>2020-08-11</td>
#       <td>2020-08-31</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.62</td>
#       <td>2020-04-16</td>
#       <td>2020-04-17</td>
#       <td>2020-04-20</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>

# %%
if False:
    r.save_most_recent_allocation("./allocations/", leverage=1.5)
