# %%
from datetime import datetime, timedelta

from stock_data_repo import StockDataRepo
from backtest import Backtester, BacktestResult
from strategies import MinVarianceAuxiliaryData, min_variance_portfolio

# %%
backtester = Backtester(datetime(2020, 4, 1, 0, 0, 0))

# %%
LONG_FACTOR_CANDIDATES = [
#     "VLUE", # Value.
#     "USMV", # Low volatility.
#     "SDY", # Dividend.
    "VXX"
]
SHORT_FACTOR_CANDIDATES = [
    "SPY", # Large cap.
    "IWF", # Growth.
    "IWM", # Small cap.
    "MTUM", # Momentum.
]
LONG_CANDIDATES = [
    "AMZN",
    "BABA",
    "BLK",
    "CRM",
    "DDOG",
    "FDX",
    "FIVN",
    "LULU",
    "NVDA",
    "PBW",
    "PINS",
    "PTON",
    "RH",
    "SNAP",
    "SE",
    "SQ",
    "TTD",
    "TWLO",
    "TSLA",
    "UPS",
    "ZG",
    "ARKK",
] + LONG_FACTOR_CANDIDATES
SHORT_CANDIDATES = [
    "VRSN",
    "CSCO",
    "IBM",
    "BOX",
    "CLDR",
    "EQR",
    "NEWR",
    "VMW",
] + SHORT_FACTOR_CANDIDATES
r = backtester.backtest(LONG_CANDIDATES, SHORT_CANDIDATES, min_variance_portfolio)
# Out:
# [*********************100%***********************]  36 of 36 completed

# %%
print("LONG FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(LONG_CANDIDATES))
print()
print("SHORT FINVIZ - ", "https://elite.finviz.com/screener.ashx?v=111&t=" + ",".join(SHORT_CANDIDATES))
# Out:
# LONG FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=AMZN,BABA,BLK,CRM,DDOG,FDX,FIVN,LULU,NVDA,PBW,PINS,PTON,RH,SNAP,SE,SQ,TTD,TWLO,TSLA,UPS,ZG,ARKK,VXX
#
# SHORT FINVIZ -  https://elite.finviz.com/screener.ashx?v=111&t=VRSN,CSCO,IBM,BOX,CLDR,EQR,NEWR,VMW,WORK,SPY,IWF,IWM,MTUM

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=3, cols=1, shared_xaxes=True)

cum_returns = (r.returns_history+1).cumprod()
fig.add_trace(go.Scatter(x=cum_returns.index, y=cum_returns), row=1, col=1)
fig.update_yaxes(type="log", row=1, col=1)


long_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in LONG_CANDIDATES]]
for (k, v) in long_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=2, col=1)
    
short_allocations = r.allocation_history[[c for c in r.allocation_history.columns if c in SHORT_CANDIDATES]]
for (k, v) in short_allocations.items():
    fig.add_trace(go.Scatter(x=r.allocation_history.index, y=v, name=k, stackgroup='one'), row=3, col=1)

fig.update_layout(
    autosize=False,
    width=1000,
    height=1200,)
fig.show()
# Out:
# <div>                            <div id="17c8e20a-cac2-443d-b854-36e91f11775b" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17c8e20a-cac2-443d-b854-36e91f11775b")) {                    Plotly.newPlot(                        "17c8e20a-cac2-443d-b854-36e91f11775b",                        [{"type": "scatter", "x": ["2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00", "2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00"], "xaxis": "x", "y": [1.0, 0.9948111026093799, 0.9922064828878598, 1.008397367013144, 1.0126882547620266, 1.0048945319154243, 1.0052097950992305, 1.0198 ...

# %% [markdown]
# # Proposed Allocation

# %% [markdown]
# ## Sorted A-Z

# %%
import plotly.express as px
data = r.allocation_history.iloc[-1]
px.bar(x=data.index, y=data)
# Out:
# <div>                            <div id="07558612-bcd9-4a63-9ded-af62c5ef451f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07558612-bcd9-4a63-9ded-af62c5ef451f")) {                    Plotly.newPlot(                        "07558612-bcd9-4a63-9ded-af62c5ef451f",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["AMZN", "ARKK", "BABA", "BLK", "BOX", "CLDR", "CRM", "CSCO", "DDOG", "EQR", "FDX", "FIVN", "IBM", "IWF", "IWM", "LULU", "MTUM", "NEWR", "NVDA", "PBW", "PINS", "PTON", "RH", "SE", "SNAP", "SPY", "SQ", "TSLA", "TTD", "TWLO", "UPS", "VMW", "VRSN", "VXX", "WORK", "ZG"], "xaxis": "x", "y": [0.08378784625295256, 0.06598668670818125, 0.04736955121322741, 0.13830792355593732, -0.05494953832939662, -0.045866437620785926, 0.05593729869014388, -0.01644835731157398, 0.014472836590079455, -0.05026841314150742, 0.08264977453296116, 0.03197337341636247, -0.006012454369765945, -0.19763796435473485, -0.12718488297187033, 0.08280008589220529, -0.20103070646338847, -0.023405625939446, 0.0716555722568177, 0.06761863860854628, 0.019239853983251023, 0.013592441485935153, 0.024157182735666742, 0.013291818767446858, 0.048786772600386524, -0.15310285591582568, 0.003457161262615419, 0.008975735452007732, 0.012712046381790855, 0.02630448786772601, 0.06446210006441917, -0.09177582134421304, -0.12611123040584069, 0.011509555507837667, -0.05357526304487869, 0.010951256173502257], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "hi ...

# %% [markdown]
# ## Sorted by weight

# %%
data[data!=0].count()
# Out:
# 36

# %%
print(data[data!=0].sort_values())
# Out:
# MTUM   -0.201031
# IWF    -0.197638
# SPY    -0.153103
# IWM    -0.127185
# VRSN   -0.126111
# VMW    -0.091776
# BOX    -0.054950
# WORK   -0.053575
# EQR    -0.050268
# CLDR   -0.045866
# NEWR   -0.023406
# CSCO   -0.016448
# IBM    -0.006012
# SQ      0.003457
# TSLA    0.008976
# ZG      0.010951
# VXX     0.011510
# TTD     0.012712
# SE      0.013292
# PTON    0.013592
# DDOG    0.014473
# PINS    0.019240
# RH      0.024157
# TWLO    0.026304
# FIVN    0.031973
# BABA    0.047370
# SNAP    0.048787
# CRM     0.055937
# UPS     0.064462
# ARKK    0.065987
# PBW     0.067619
# NVDA    0.071656
# FDX     0.082650
# LULU    0.082800
# AMZN    0.083788
# BLK     0.138308
# Name: 2020-10-22 00:00:00, dtype: float64

# %%
import pyfolio as pf
pf.create_returns_tear_sheet(r.returns_history)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-04-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-22</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>6</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>149.252%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>67.91%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>11.205%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>8.22</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>68.22</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-2.188%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>3.63</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>18.09</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.81</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.046%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.19</td>
#       <td>2020-05-19</td>
#       <td>2020-05-29</td>
#       <td>2020-06-04</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.94</td>
#       <td>2020-10-07</td>
#       <td>2020-10-12</td>
#       <td>2020-10-14</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.71</td>
#       <td>2020-06-24</td>
#       <td>2020-06-26</td>
#       <td>2020-07-01</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.01</td>
#       <td>2020-08-19</td>
#       <td>2020-08-20</td>
#       <td>2020-08-25</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.97</td>
#       <td>2020-04-27</td>
#       <td>2020-04-28</td>
#       <td>2020-05-06</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>

# %%
if True:
    r.save_most_recent_allocation("./allocations/", leverage=1.5)
